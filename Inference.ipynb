# %%
import pandas as pd
import numpy as np
import pickle
import ast

# %% [markdown]
# # Load Data

# %%
df_inf = pd.read_csv('aug_test.csv')
df_inf
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# 2      No relevent experience       no_enrollment     High School
# 3     Has relevent experience       no_enrollment         Masters
# 4     Has relevent experience       no_enrollment        Graduate
# ...                       ...                 ...             ...
# 2124   No relevent experience       no_enrollment        Graduate
# 2125  Has relevent experience       no_enrollment         Masters
# 2126   No relevent experience       no_enrollment  Primary School
# 2127  Has relevent experience    Full time course     High School
# 2128  Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size   company_type last_new_job  \
# 0                STEM          9          <10            NaN            1
# 1                STEM          5          NaN        Pvt Ltd            1
# 2                 NaN         <1          NaN        Pvt Ltd        never
# 3                STEM         11        10/49        Pvt Ltd            1
# 4                STEM        >20       10000+        Pvt Ltd           >4
# ...               ...        ...          ...            ...          ...
# 2124       Humanities         16          NaN  Public Sector            4
# 2125             STEM         18          NaN            NaN            2
# 2126              NaN          3          NaN        Pvt Ltd        never
# 2127              NaN          7      100-500  Public Sector            1
# 2128             STEM         15       10000+        Pvt Ltd            2
#
#       training_hours
# 0                 21
# 1                 98
# 2                 15
# 3                 39
# 4                 72
# ...              ...
# 2124              15
# 2125              30
# 2126              18
# 2127              84
# 2128              11
#
# [2129 rows x 13 columns]

# %%
def klasifikasi_experience(experience):
    if pd.isna(experience):
        pass
    elif experience in ['<1','1', '2', '3','4', '5']:
        return 'Junior'
    elif experience in ['6', '7', '8', '9', '10']:
        return 'Intermediate'
    elif experience in ['11','12','13' ,'14','15']:
        return 'Senior'
    else:
        return 'Veteran'

# %% [markdown]
# Used to change the experience column to an experience category column

# %%
df_inf['experience_category'] = df_inf['experience'].apply(klasifikasi_experience)
df_inf
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# 2      No relevent experience       no_enrollment     High School
# 3     Has relevent experience       no_enrollment         Masters
# 4     Has relevent experience       no_enrollment        Graduate
# ...                       ...                 ...             ...
# 2124   No relevent experience       no_enrollment        Graduate
# 2125  Has relevent experience       no_enrollment         Masters
# 2126   No relevent experience       no_enrollment  Primary School
# 2127  Has relevent experience    Full time course     High School
# 2128  Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size   company_type last_new_job  \
# 0                STEM          9          <10            NaN            1
# 1                STEM          5          NaN        Pvt Ltd            1
# 2                 NaN         <1          NaN        Pvt Ltd        never
# 3                STEM         11        10/49        Pvt Ltd            1
# 4                STEM        >20       10000+        Pvt Ltd           >4
# ...               ...        ...          ...            ...          ...
# 2124       Humanities         16          NaN  Public Sector            4
# 2125             STEM         18          NaN            NaN            2
# 2126              NaN          3          NaN        Pvt Ltd        never
# 2127              NaN          7      100-500  Public Sector            1
# 2128             STEM         15       10000+        Pvt Ltd            2
#
#       training_hours experience_category
# 0                 21        Intermediate
# 1                 98              Junior
# 2                 15              Junior
# 3                 39              Senior
# 4                 72             Veteran
# ...              ...                 ...
# 2124              15             Veteran
# 2125              30             Veteran
# 2126              18              Junior
# 2127              84        Intermediate
# 2128              11              Senior
#
# [2129 rows x 14 columns]

# %% [markdown]
# # Load Model

# %%
# memanggil model yang sudah di simpan
with open('pipeline.pkl', 'rb') as file_1:
  pipeline = pickle.load(file_1)


with open('model_svc_best.pkl', 'rb') as file_2:
  model_svc = pickle.load(file_2)

with open('list_num_columns.txt', 'r') as file_3:
  list_num_columns = file_3.read()

with open('list_cat_columns.txt', 'r') as file_4:
  list_cat_columns = file_4.read()

# %%
# merubah nama-nama column menjadi list agar mudah dalam pemanggilan
list_num_columns = ast.literal_eval(list_num_columns)
list_cat_columns = ast.literal_eval(list_cat_columns)

# %%
# memasukan kolom yang akan digunakan untuk modeling
df_inf_fix = df_inf[list_cat_columns+list_num_columns]
df_inf_fix
# Out:
#       gender      relevent_experience enrolled_university education_level  \
# 0       Male  Has relevent experience    Full time course        Graduate
# 1     Female  Has relevent experience       no_enrollment        Graduate
# 2       Male   No relevent experience       no_enrollment     High School
# 3       Male  Has relevent experience       no_enrollment         Masters
# 4       Male  Has relevent experience       no_enrollment        Graduate
# ...      ...                      ...                 ...             ...
# 2124    Male   No relevent experience       no_enrollment        Graduate
# 2125    Male  Has relevent experience       no_enrollment         Masters
# 2126    Male   No relevent experience       no_enrollment  Primary School
# 2127    Male  Has relevent experience    Full time course     High School
# 2128    Male  Has relevent experience       no_enrollment         Masters
#
#      major_discipline company_size   company_type last_new_job  \
# 0                STEM          <10            NaN            1
# 1                STEM          NaN        Pvt Ltd            1
# 2                 NaN          NaN        Pvt Ltd        never
# 3                STEM        10/49        Pvt Ltd            1
# 4                STEM       10000+        Pvt Ltd           >4
# ...               ...          ...            ...          ...
# 2124       Humanities          NaN  Public Sector            4
# 2125             STEM          NaN            NaN            2
# 2126              NaN          NaN        Pvt Ltd        never
# 2127              NaN      100-500  Public Sector            1
# 2128             STEM       10000+        Pvt Ltd            2
#
#      experience_category  city_development_index
# 0           Intermediate                   0.827
# 1                 Junior                   0.920
# 2                 Junior                   0.624
# 3                 Senior                   0.827
# 4                Veteran                   0.920
# ...                  ...                     ...
# 2124             Veteran                   0.920
# 2125             Veteran                   0.897
# 2126              Junior                   0.887
# 2127        Intermediate                   0.804
# 2128              Senior                   0.804
#
# [2129 rows x 10 columns]

# %%
# melakukan reprocessing menggunakan pipeline
df_inf_prep = pipeline.transform(df_inf_fix)
df_inf_prep
# Out:
# array([[2.   , 2.   , 0.   , ..., 0.   , 1.   , 0.827],
#        [0.   , 2.   , 2.   , ..., 0.   , 1.   , 0.92 ],
#        [0.   , 1.   , 2.   , ..., 0.   , 1.   , 0.624],
#        ...,
#        [0.   , 0.   , 2.   , ..., 0.   , 1.   , 0.887],
#        [2.   , 1.   , 3.   , ..., 1.   , 0.   , 0.804],
#        [0.   , 3.   , 7.   , ..., 0.   , 1.   , 0.804]])

# %%
# memprediksi menggunakan model yang sudah didapatkan dari ipynb utama
y_inf_predict = model_svc.predict(df_inf_prep)
y_inf_predict = pd.DataFrame(y_inf_predict,columns=['Target'])
y_inf_predict
# Out:
#       Target
# 0        1.0
# 1        1.0
# 2        1.0
# 3        0.0
# 4        0.0
# ...      ...
# 2124     0.0
# 2125     0.0
# 2126     1.0
# 2127     1.0
# 2128     0.0
#
# [2129 rows x 1 columns]

# %%
# menggabungkan data prediksi dengan data awal.
df_final_predict = pd.concat([df_inf,y_inf_predict],axis=1)
df_final_predict
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# 2      No relevent experience       no_enrollment     High School
# 3     Has relevent experience       no_enrollment         Masters
# 4     Has relevent experience       no_enrollment        Graduate
# ...                       ...                 ...             ...
# 2124   No relevent experience       no_enrollment        Graduate
# 2125  Has relevent experience       no_enrollment         Masters
# 2126   No relevent experience       no_enrollment  Primary School
# 2127  Has relevent experience    Full time course     High School
# 2128  Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size   company_type last_new_job  \
# 0                STEM          9          <10            NaN            1
# 1                STEM          5          NaN        Pvt Ltd            1
# 2                 NaN         <1          NaN        Pvt Ltd        never
# 3                STEM         11        10/49        Pvt Ltd            1
# 4                STEM        >20       10000+        Pvt Ltd           >4
# ...               ...        ...          ...            ...          ...
# 2124       Humanities         16          NaN  Public Sector            4
# 2125             STEM         18          NaN            NaN            2
# 2126              NaN          3          NaN        Pvt Ltd        never
# 2127              NaN          7      100-500  Public Sector            1
# 2128             STEM         15       10000+        Pvt Ltd            2
#
#       training_hours experience_category  Target
# 0                 21        Intermediate     1.0
# 1                 98              Junior     1.0
# 2                 15              Junior     1.0
# 3                 39              Senior     0.0
# 4                 72             Veteran     0.0
# ...              ...                 ...     ...
# 2124              15             Veteran     0.0
# 2125              30             Veteran     0.0
# 2126              18              Junior     1.0
# 2127              84        Intermediate     1.0
# 2128              11              Senior     0.0
#
# [2129 rows x 15 columns]
